# %% [markdown]
# # BIBLIOTECA PANDAS

# %% [markdown]
# ## 1 Importação das bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ## 2 Criação do DataFrame a partir do CSV

# %%
dados = pd.read_csv(r'C:\Users\anderson51599526\Desktop\python_senac\pandas\Vendas.csv', sep=';')

# %% [markdown]
# ## Exibição do DataFrame

# %%
display(dados)
# Out:
#           Data                     ID Loja           Produto  Quantidade  \
# 0   01/12/2019           Iguatemi Campinas   Bermuda Estampa           1
# 1   01/12/2019          Iguatemi Esplanada    Bermuda Xadrez           1
# 2   01/12/2019              Norte Shopping           Bermuda           2
# 3   01/12/2019           Iguatemi Campinas  Bermuda Listrado           3
# 4   01/12/2019           Iguatemi Campinas     Bermuda Linho           3
# 5   03/12/2019           Iguatemi Campinas    Bermuda Xadrez           1
# 6   03/12/2019         Bourbon Shopping SP  Bermuda Listrado           1
# 7   03/12/2019         Bourbon Shopping SP    Bermuda Xadrez           3
# 8   03/12/2019         Bourbon Shopping SP   Bermuda Estampa           1
# 9   04/12/2019  Center Shopping Uberlândia    Bermuda Xadrez           4
# 10  04/12/2019          Iguatemi Esplanada           Bermuda           1
# 11  04/12/2019         Bourbon Shopping SP   Bermuda Estampa           2
# ...

# %% [markdown]
# ## Ler arquivo Excel

# %%
dados2 = pd.read_excel(r'C:\Users\anderson51599526\Desktop\python_senac\pandas\aula8nov\mercado.xlsx')

# %% [markdown]
# ## Mostrar o DataFrame

# %%
display(dados2)
# Out:
#       MÊS ESTADO  PRODUTO          CLIENTE  QUANT.  VALOR  TIPO DE PRODUTO  \
# 0     JAN     GO  CERVEJA        CARREFOUR    5000   10000        ALCOLICO
# 1     JAN     SP  CERVEJA            EXTRA    2000    4000        ALCOLICO
# 2     JAN     MG     SUCO           COMPER   23000   46000         NATURAL
# 3     JAN     GO     SUCO            EXTRA   10000   20000         NATURAL
# 4     JAN     TO  CERVEJA        CARREFOUR   24300   48600        ALCOLICO
# 5     JAN     TO     SUCO           COMPER   23500   47000         NATURAL
# 6     JAN     GO    VINHO         SUPERCEI   67000  134000        ALCOLICO
# 7     JAN     GO    VODKA          MINIBOX   34000   68000        ALCOLICO
# 8     FEV     RJ     WISK         SUPERCEI  230000  460000        ALCOLICO
# 9     FEV     MG    VINHO           COMPER   12000   24000        ALCOLICO
# 10    FEV     MG     WISK            EXTRA   14000   28000        ALCOLICO
# ...

# %% [markdown]
# ## Criando DataFrame

# %%
dados3 = pd.read_excel(r'C:\Users\anderson51599526\Desktop\python_senac\pandas\aula8nov\tabela_municipios.xlsx')

# %% [markdown]
# ## Exibir o DataFrame

# %%
display(dados3)
# Out:
#       UF           Nome_UF  Mesorregião Geográfica   Nome_Mesorregião  \
# 0     11          Rondônia                       2  Leste Rondoniense
# 1     11          Rondônia                       2  Leste Rondoniense
# 2     11          Rondônia                       2  Leste Rondoniense
# 3     11          Rondônia                       2  Leste Rondoniense
# 4     11          Rondônia                       2  Leste Rondoniense
# ...   ..               ...                     ...                ...
# 5565  52             Goiás                       5         Sul Goiano
# 5566  52             Goiás                       5         Sul Goiano
# 5567  52             Goiás                       4       Leste Goiano
# 5568  52             Goiás                       4       Leste Goiano
# 5569  53  Distrito Federal                       1   Distrito Federal
#
#       Microrregião Geográfica    Nome_Microrregião  Município  \
# 0                           6               Cacoal         15
# ...
